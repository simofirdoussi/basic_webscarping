# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get("https://www.avito.ma/fr/maroc/voitures-%C3%A0_vendre?cb=13&mo=logan&fl=1", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content

# %%
soup = BeautifulSoup(c,"html.parser")

# %%
titles = soup.find_all("h2",{"class":"fs14"}) #extracting the titles

# %%
cities = soup.find_all("span",{"class":"item-info-extra fs14"}) #Extracting the cities names

# %%
price_values = soup.find_all("span",{"class":"price_value"}) #Extracting the price values of each title

# %%
l = []
for i in range (len(titles)):
    d = {}
    d["Type"] = (titles[i].text)
    d["City"] = (cities[i].text.replace("\n","").replace(' -Annonce de professionnel', ''))
    d["Price"] = (price_values[i].text)
    if d["Price"] == "\xa0":# Condition for the case where the price isnt specified
        d["Price"] = "NONE"
    
    l.append(d)

# %%
l
# Out:
# [{'Type': ' Dacia Logan Diesel -2017 ', 'City': 'Agadir', 'Price': 'NONE'},
#  {'Type': ' dacia logane -2018 ', 'City': 'Casablanca', 'Price': '92 000'},
#  {'Type': ' Dacia logan diesel tottoption 1er main -2016 ',
#   'City': 'Marrakech',
#   'Price': '80 000'},
#  {'Type': ' Dacia logan -2017 ', 'City': 'Marrakech', 'Price': 'NONE'},
#  {'Type': ' Voiture -2006 ', 'City': 'Rabat', 'Price': 'NONE'},
#  {'Type': ' Dacia Logan Diesel -2014 ', 'City': 'Meknès', 'Price': '78 000'},
#  {'Type': ' Dacia logane prestige 17 tactile -2017 ',
#   'City': 'Casablanca',
#   'Price': '86 000'},
#  {'Type': ' Dacia Logan op -2017 ', 'City': 'Ain Harrouda', 'Price': '88 000'},
#  {'Type': ' Dacia Logan -2017 ', 'City': 'Agadir', 'Price': 'NONE'},
#  {'Type': ' Dacia Logan tt -2017 ', 'City': 'Casablanca', 'Price': '88 000'},
#  {'Type': ' dacia logan -2013 ', 'City': 'Agadir', 'Price': '69 000'},
#  {'Type': ' dacia logan -2017 ', 'City': 'Casablanca', 'Price': '80 000'},
#  {'Type': ' Dacia Logan Diesel -2015 ', 'City': 'Fès', 'Price': 'NONE'},
#  {'Type': ' Dacia Logan Diesel -2015 ',
#   'City': 'Casablanca',
#   'Price': '83 000'},
#  {'Type': ' Logan 1 ère main diesel -2017 ', 'City': 'Fès', 'Price': '88 000'},
#  {'Type': ' Dacia Logan -2018 ', 'City': 'Marrakech', 'Price': '92 000'},
#  {'Type': ' Dacia logane -2017 ', 'City': 'Casablanca', 'Price': '95 000'},
#  {'Type': ' Dacia Logan Diesel -2016 ', 'City': 'Salé', 'Price': 'NONE'},
#  {'Type': ' Dacia LOGAN Diesel tout option 6ch -2015 ',
#   'City': 'Casablanca',
#   'Price': 'NONE'},
#  {'Type': ' Dacia logan -2008 ', 'City': 'Casablanca', 'Price': '56 000'},
#  {'Type': ' logan tout options diesel -2014 ',
#   'City': 'Mohammedia',
#   'Price': '79 000'},
#  {'Type': ' dacia logan -2015 ', 'City': 'Casablanca', 'Price': '70 000'},
#  {'Type': ' Dacia Logan -2016 ', 'City': 'Meknès', 'Price': '87 000'},
#  {'Type': ' dacia logan diesel toute options clima 2ème -2009 ',
#   'City': 'Casablanca',
#   'Price': '66 000'},
#  {'Type': ' Dacia Logan -2009 ', 'City': 'Rabat', 'Price': '55 000'},
#  {'Type': ' Dacia logan -2013 ', 'City': 'Tanger', 'Price': '65 000'},
#  {'Type': ' Dacia Logan diesel -2017 ', 'City': 'Fès', 'Price': '98 000'},
#  {'Type': ' Dacia Logan Diesel 1er main -2015 ',
#   'City': 'Casablanca',
#   'Price': '87 000'},
#  {'Type': ' Dacia Logan diesel première main -2018 ',
#   'City': 'Mohammedia',
#   'Price': '90 000'},
#  {'Type': ' Dacia Logan Diesel -2010 ',
#   'City': 'Chefchaouen',
#   'Price': '56 000'},
#  {'Type': ' DACIA LOGAN -2012 ', 'City': 'Casablanca', 'Price': '75 000'},
#  {'Type': ' dacia logan tt options -2016 ',
#   'City': 'Taroudant',
#   'Price': '89 000'},
#  {'Type': ' Dacia Logan -2011 ', 'City': 'Agadir', 'Price': '65 000'},
#  {'Type': ' dacia logan -2013 ', 'City': 'Kénitra', 'Price': '78 000'},
#  {'Type': ' Dacia Logan Diesel 1ère main -2017 ',
#   'City': 'Marrakech',
#   'Price': '91 000'}]

# %%
df = pd.DataFrame(l) #creating a dataframe
df
# Out:
#                                                  Type          City   Price
# 0                           Dacia Logan Diesel -2017         Agadir    NONE
# 1                                 dacia logane -2018     Casablanca  92 000
# 2       Dacia logan diesel tottoption 1er main -2016      Marrakech  80 000
# 3                                  Dacia logan -2017      Marrakech    NONE
# 4                                      Voiture -2006          Rabat    NONE
# 5                           Dacia Logan Diesel -2014         Meknès  78 000
# 6             Dacia logane prestige 17 tactile -2017     Casablanca  86 000
# 7                               Dacia Logan op -2017   Ain Harrouda  88 000
# 8                                  Dacia Logan -2017         Agadir    NONE
# 9                               Dacia Logan tt -2017     Casablanca  88 000
# 10                                 dacia logan -2013         Agadir  69 000
# 11                                 dacia logan -2017     Casablanca  80 000
# 12                          Dacia Logan Diesel -2015            Fès    NONE
# 13                          Dacia Logan Diesel -2015     Casablanca  83 000
# 14                     Logan 1 ère main diesel -2017            Fès  88 000
# 15                                 Dacia Logan -2018      Marrakech  92 000
# 16                                Dacia logane -2017     Casablanca  95 000
# 17                          Dacia Logan Diesel -2016           Salé    NONE
# 18          Dacia LOGAN Diesel tout option 6ch -2015     Casablanca    NONE
# 19                                 Dacia logan -2008     Casablanca  56 000
# 20                   logan tout options diesel -2014     Mohammedia  79 000
# 21                                 dacia logan -2015     Casablanca  70 000
# 22                                 Dacia Logan -2016         Meknès  87 000
# 23   dacia logan diesel toute options clima 2ème -...    Casablanca  66 000
# 24                                 Dacia Logan -2009          Rabat  55 000
# 25                                 Dacia logan -2013         Tanger  65 000
# 26                          Dacia Logan diesel -2017            Fès  98 000
# 27                 Dacia Logan Diesel 1er main -2015     Casablanca  87 000
# 28            Dacia Logan diesel première main -2018     Mohammedia  90 000
# 29                          Dacia Logan Diesel -2010    Chefchaouen  56 000
# 30                                 DACIA LOGAN -2012     Casablanca  75 000
# 31                      dacia logan tt options -2016      Taroudant  89 000
# 32                                 Dacia Logan -2011         Agadir  65 000
# 33                                 dacia logan -2013        Kénitra  78 000
# 34                Dacia Logan Diesel 1ère main -2017      Marrakech  91 000

# %%
df.to_csv("Output.csv") #storing the poutput in a csv file
